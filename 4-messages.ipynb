# %% [markdown]
# ### Messages
# Messages are the fundamental unit of context for models in LangChain. They represent the input and output of models, carrying both the content and metadata needed to represent the state of a conversation when interacting with an LLM. Messages are objects that contain:
#
# * Role - Identifies the message type (e.g. system, user)
# * Content - Represents the actual content of the message (like text, images, audio, documents, etc.)
# * Metadata - Optional fields such as response information, message IDs, and token usage
#
# LangChain provides a standard message type that works across all model providers, ensuring consistent behavior regardless of the model being called.

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(model="granite4.1:3b", model_provider="ollama")
response = model.invoke("What is artificial intelligence?")

# %%
print(response)
# Out:
# content='Artificial Intelligence (AI) refers to the simulation of human intelligence processes by machines, particularly computer systems. These processes include learning (the ability to adapt and improve from experience), reasoning (the capability to make logical inferences based on data), and self-correction. AI can be categorized into several types based on its functionality and complexity:\n\n1. **Narrow or Weak AI**: Designed to perform a narrow task (e.g., playing chess, recognizing speech). These systems are designed and programmed for specific functions and cannot generalize their learning beyond their programmed tasks.\n\n2. **General or Strong AI**: Hypothetical AI that could understand or learn any intellectual task that a human being can. This form of AI does not currently exist and is still largely theoretical.\n\n3. **Machine Learning (ML)**: A subset of AI that involves algorithms and statistical models that enable software applications to become more accurate in predicting outcomes without being explicitly programmed to do so. ML focuses on the development of computer programs that can change their behavior based on the data they are exposed to, a capability known as "learning."\n\n4. **Deep Learning**: A subset of machine learning involving neural networks with many layers (hence "deep"). Deep learning algorithms have proven particularly effective for image and speech recognition tasks.\n\n5. **Natural Language Processing (NLP)**: Allows computers to understand, interpret, and generate human language. This is used in chatbots, voice assistants, and translation services.\n\n6. **Computer Vision**: Enables machines to interpret and make decisions based on visual data from the world around them. Applications include facial recognition, object detection, and autonomous vehicles.\n\nAI technologies are being applied across various fields such as healthcare (e.g., diagnosing diseases), finance (fraud detection), transportation (self-driving cars), customer service (chatbots), and entertainment (personalized recommendations). The development of AI involves interdisciplinary approaches including computer science, psychology, neuroscience, linguistics, and philosophy. As research progresses, the potential applications and ethical considerations surrounding AI continue to expand and evolve.' additional_kwargs={} response_metadata={'model': 'granite4.1:3b', 'created_at': '2026-05-24T19:46:03.2289507Z', 'done': True, 'done_reason': 'stop', 'total_duration': 35838019100, 'load_duration': 1412490400, 'prompt_eval_count': 13, 'prompt_eval_duration': 377311300, 'eval_count': 411, 'eval_duration': 31230287000, 'logprobs': None, 'model_name': 'granite4.1:3b', 'model_provider': 'ollama'} id='lc_run--019e5b85-5d5d-7ee3-8ed6-f0ae410de41d-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 411, 'total_tokens': 424}

# %% [markdown]
# ### Text Prompts
# Text prompts are strings - ideal for straightforward generation tasks where you don’t need to retain conversation history.

# %%
model.invoke("what is langchain")
# Out:
# AIMessage(content="LangChain is an open-source framework built on top of LangChain AI, designed to simplify the development of applications that utilize large language models (LLMs). It provides a set of tools and components that make it easier for developers to build applications that leverage natural language processing capabilities offered by LLMs.\n\nKey features and use cases of LangChain include:\n\n1. **Chain Multiple Prompts**: Allows you to chain multiple prompts together, enabling more complex interactions with the model. For example, you can start a conversation with an initial prompt and then follow up with additional questions based on the model's previous responses.\n\n2. **Retrieval-Augmented Generation (RAG)**: LangChain supports building RAG applications where models can be informed by external data sources. This is useful for creating more context-aware systems that can answer questions based on specific documents or databases in addition to general knowledge.\n\n3. **Vector Stores**: It integrates with various vector stores like Chroma, Faiss, and Milvus, which allow you to efficiently store and retrieve embeddings of text data. This enables efficient similarity searches, making it possible for models to find relevant information quickly within large datasets.\n\n4. **Agent Frameworks**: LangChain provides a modular architecture that allows the creation of agents with different behaviors (e.g., planning, execution) using plugins like the Autoregressive Agent and Reinforcement Learning from Human Feedback (RLHF). These agents can interact with external tools or APIs to perform tasks beyond just generating text.\n\n5. **Prompt Engineering**: It offers utilities for prompt engineering, helping developers design more effective prompts that guide the model's responses in desired directions. This includes techniques like filling templates, parameterizing prompts, and managing chains of thought.\n\n6. **Integration with Web3**: LangChain has support for building decentralized applications (dApps) by integrating with blockchain technologies, enabling the creation of on-chain smart contracts and off-chain tools that interact with LLMs in a secure and decentralized manner.\n\nLangChain is particularly useful for developers who want to harness the power of large language models without getting bogged down by low-level details like data preprocessing, model serving, or complex prompt engineering. It abstracts many of these concerns away, allowing users to focus on building more sophisticated applications that can understand and generate human-like text based on specific contexts or tasks.", additional_kwargs={}, response_metadata={'model': 'granite4.1:3b', 'created_at': '2026-05-24T19:47:54.5544746Z', 'done': True, 'done_reason': 'stop', 'total_duration': 38997572700, 'load_duration': 60604000, 'prompt_eval_count': 12, 'prompt_eval_duration': 256560900, 'eval_count': 469, 'eval_duration': 35686109200, 'logprobs': None, 'model_name': 'granite4.1:3b', 'model_provider': 'ollama'}, id='lc_run--019e5b87-03e3-7991-9eed-8193574c0943-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 469, 'total_tokens': 481})

# %% [markdown]
# Use text prompts when:
#
# You have a single, standalone request
# You don’t need conversation history
# You want minimal code complexity
#
# ### Message Prompts
# Alternatively, you can pass in a list of messages to the model by providing a list of message objects.
#
# ### Message types
#
# System message - Tells the model how to behave and provide context for interactions
# Human message - Represents user input and interactions with the model
# AI message - Responses generated by the model, including text content, tool calls, and metadata
# Tool message - Represents the outputs of tool calls
#
# ### System Message
# A SystemMessage represent an initial set of instructions that primes the model’s behavior. You can use a system message to set the tone, define the model’s role, and establish guidelines for responses.
#
# ### Human Message
# A HumanMessage represents user input and interactions. They can contain text, images, audio, files, and any other amount of multimodal content.
#
# ### AI Message
# An AIMessage represents the output of a model invocation. They can include multimodal data, tool calls, and provider-specific metadata that you can later access.
#
# ### Tool Message
# For models that support tool calling, AI messages can contain tool calls. Tool messages are used to pass the results of a single tool execution back to the model.

# %%
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
messages = [
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="What is artificial intelligence?"),
]

response=model.invoke(messages)
response.content
# Out:
# "Artificial Intelligence (AI) refers to the simulation of human intelligence in machines that are programmed to think and learn like humans. These systems can perform tasks such as visual perception, speech recognition, decision-making, and language translation. AI encompasses various technologies including machine learning, deep learning, natural language processing, robotics, and computer vision. It's used across numerous industries for automation, data analysis, improving efficiency, and creating innovative solutions to complex problems."

# %%
system_msg = SystemMessage("You are a helpful coding assistant.")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]
response = model.invoke(messages)
print(response.content)
# Out:
# Creating a REST API involves several steps, and the exact process can vary depending on the programming language and framework you choose. However, here's a general outline of the steps you'll typically follow:
#
# 1. **Choose a Programming Language and Framework**: Select a programming language (e.g., Python, Java, Node.js) and a web framework that supports RESTful API development (e.g., Flask for Python, Spring Boot for Java, Express.js for Node.js).
#
# 2. **Set Up Your Development Environment**: Install the necessary tools and libraries for your chosen language and framework. This usually includes a code editor or IDE, a package manager (like pip for Python), and any required runtime environments.
#
# 3. **Design Your API**: Define the endpoints (URLs) and HTTP methods (GET, POST, PUT, DELETE, etc.) that your API will support. Determine the data models (schemas) for your resources and how they will be represented in JSON or XML format.
#
# 4. **Create a Database Schema**: If your application requires persistent storage, design your database schema to match the data models defined earlier. Choose an appropriate database management system (DBMS) based on your requirements (e.g., MySQL, PostgreSQL, MongoDB).
#
# 5. **Implement API Endpoints**:
#    - Define functions or classes for each API endpoint that will handle incoming requests.
#    - Use routing mechanisms provided by your framework to map HTTP methods and URLs to specific handler functions.
#    - Implement the logic required to process the request (e.g., query database records, perform calculations).
#    - Return appropriate responses in JSON or XML format, including status codes (e.g., 200 for success, 404 for not found).
#
# 6. **Handle Data Validation and Error Handling**:
#    - Validate incoming data to ensure it meets your expected formats and constraints.
#    - Implement error handling mechanisms to gracefully handle invalid requests, database errors, or other exceptions.
#
# 7. **Test Your API**: Write unit tests and integration tests to verify that each endpoint behaves as expected. Use tools like Postman or cURL to manually test your endpoints with sample data.
#
# 8. **Secure Your API**:
#    - Implement authentication mechanisms (e.g., JWT tokens, OAuth) to ensure only authorized users can access protected resources.
#    - Validate and sanitize user input to prevent common security vulnerabilities like SQL injection or cross-site scripting (XSS).
#
# 9. **Deploy Your API**: Choose a hosting platform (e.g., Heroku, AWS, DigitalOcean) that supports the technology stack you're using. Set up your application in a production environment and configure necessary settings like database connections and server configurations.
#
# 10. **Document Your API**: Create clear documentation outlining how to use your API, including endpoint descriptions, request/response formats, authentication requirements, and error codes. Tools like Swagger or Postman can help generate interactive API documentation.
#
# Remember, the specific implementation details will vary based on your chosen technology stack. It's a good idea to refer to the official documentation of your selected framework for detailed instructions on building REST APIs with that particular toolset.

# %%
## Detailed info to the LLM through System message
from langchain.messages import SystemMessage, HumanMessage

system_msg = SystemMessage("""
You are a senior Python developer with expertise in web frameworks.
Always provide code examples and explain your reasoning.
Be concise but thorough in your explanations.
""")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]
response = model.invoke(messages)
print(response.content)
# Out:
# Creating a REST API in Python typically involves using a web framework such as Flask or FastAPI, which simplifies the process of defining endpoints, handling HTTP methods (GET, POST, PUT, DELETE), and managing request/response data. Below is a step‑by‑step guide using **FastAPI**, a modern, fast (high-performance) Web Framework for building APIs with Python 3.6+ based on standard Python type annotations.
#
# ### Step 1: Install FastAPI & Dependencies
#
# First, ensure you have `fastapi` and an ASGI server like `uvicorn` installed:
#
# ```bash
# pip install fastapi uvicorn[standard]
# ```
#
# ### Step 2: Define Your Data Model (Optional)
#
# If your API deals with structured data (e.g., user profiles), use a library like Pydantic to define models. This gives you type safety and automatic validation.
#
# ```python
# from pydantic import BaseModel
#
# class Item(BaseModel):
#     id: int
#     name: str
#     description: str = ""
# ```
#
# ### Step 3: Create the API Application
#
# Create an `app.py` file (or any other module name) and set up your FastAPI application.
#
# ```python
# from fastapi import FastAPI, HTTPException
# from pydantic import BaseModel
#
# app = FastAPI()
#
# # Optional model definition (see above)
# class Item(BaseModel):
#     id: int
#     name: str
#     description: str = ""
# ```
#
# ### Step 4: Define Endpoints
#
# FastAPI automatically parses request bodies based on type hints. Here’s how to implement common CRUD endpoints.
#
# ```python
# # Inapp.py
#
# from typing import List
# from fastapi import HTTPException, status
# from pydantic import BaseModel
#
# # Example list of items (in-memory for simplicity)
# items: List[Item] = []
#
# @app.get("/items/", response_model=List[Item])
# def read_items(skip: int = 0, limit: int = 10):
#     """Return a paginated list of all items."""
#     return items[skip : skip + limit]
#
# @app.get("/items/{item_id}", response_model=Item)
# def get_item(item_id: int):
#     """Retrieve a specific item by its ID."""
#     for item in items:
#         if item.id == item_id:
#             return item
#     raise HTTPException(status_code=status.HTTP_404_.NOT_FOUND, detail="Item not found")
#
# @app.post("/items/", response_model=Item)
# def create_item(new_item: Item):
#     """Create a new item."""
#     items.append(new_item)
#     return new_item
#
# @app.put("/items/{item_id}", response_model=Item)
# def update_item(item_id: int, updated_item: Item):
#     """Update an existing item by its ID."""
#     for i, item in enumerate(items):
#         if item.id == item_id:
#             items[i] = updated_item
#             return updated_item
#     raise HTTPException(status_code=status.HTTP_404.NOT_FOUND, detail="Item not found")
#
# @app.delete("/items/{item_id}")
# def delete_item(item_id: int):
#     """Delete an item by its ID."""
#     global items
#     items = [item for item in items if item.id != item_id]
# ```
#
# ### Step 5: Run the API Server
#
# Use `uvicorn` to start the ASGI server:
#
# ```bash
# uvicorn app:app --reload
# ```
#
# This command tells Uvicorn to load the FastAPI application from `app.py` and watch for changes (`--reload`).
#
# ### Step 6: Test Your API (Optional)
#
# You can test your endpoints using tools like **curl**, **Postman**, or built‑in browser support in VSCode.
#
# Example with curl:
#
# ```bash
# # Create a new item
# curl -X POST "http://127.0.0.1:8000/items/" -H "Content-Type: application/json" -d '{"id": 1, "name": "Sample Item", "description": "This is a sample."}'
#
# # Get all items
# curl http://127.0.0.1:8000/items/
#
# # Get a specific item
# curl http://127.0.0.1:8000/items/1
#
# # Update an item
# curl -X PUT "http://127.0.0.1:8000/items/1" -H "Content-Type: application/json" -d '{"id": 1, "name": "Updated Item", "description": "Updated description."}'
#
# # Delete an item
# curl -X DELETE "http://127.0.0.1:8000/items/1"
# ```
#
# ### Key Concepts Explained
#
# - **Type Annotations**: FastAPI leverages Python type hints (`int`, `str`) to automatically validate incoming request bodies and return proper data types.
# - **HTTPException**: Used for handling 404 errors when a requested item does not exist, providing clear feedback to clients.
# - **Uvicorn**: An ASGI server that runs the FastAPI application. It’s lightweight and fast, ideal for production or development environments.
# - **CRUD Operations**: The example demonstrates basic Create‑Read‑Update‑Delete (CRUD) operations typical of REST APIs.
#
# ### Extending Your API
#
# - **Database Integration**: Replace `items` with a database connection using SQLAlchemy or Django ORM to persist data.
# - **Security**: Add authentication middleware (e.g., OAuth2, JWT) for protected endpoints.
# - **Documentation**: FastAPI automatically generates Swagger UI documentation at `/docs`, which is helpful for developers consuming your API.
#
# By following these steps and leveraging FastAPI’s conventions, you can quickly build a robust RESTful service in Python. Adjust the model definitions and endpoint logic according to your specific domain requirements.

# %%
## Message Metadata
human_msg = HumanMessage(
    content="Hello!",
    name="alice",  # Optional: identify different users
    id="msg_123",  # Optional: unique identifier for tracing
)

# %%
response = model.invoke([
  human_msg
])
response
# Out:
# AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'model': 'granite4.1:3b', 'created_at': '2026-05-24T19:56:34.8926934Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1039832600, 'load_duration': 62818900, 'prompt_eval_count': 10, 'prompt_eval_duration': 242453300, 'eval_count': 10, 'eval_duration': 676684300, 'logprobs': None, 'model_name': 'granite4.1:3b', 'model_provider': 'ollama'}, id='lc_run--019e5b8f-88bb-7231-9853-5ff35b843e7c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 10, 'total_tokens': 20})

# %%
from langchain.messages import AIMessage, SystemMessage, HumanMessage

# Create an AI message manually (e.g., for conversation history)
ai_msg = AIMessage("I'd be happy to help you with that question!")

# Add to conversation history
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,  # Insert as if it came from the model
    HumanMessage("Great! What's 2+2?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# 2 + 2 equals 4.

# %%
response.usage_metadata
# Out:
# {'input_tokens': 53, 'output_tokens': 9, 'total_tokens': 62}

# %%
from langchain.messages import AIMessage
from langchain.messages import ToolMessage

# After a model makes a tool call
# (Here, we demonstrate manually creating the messages for brevity)
ai_message = AIMessage(
    content=[],
    tool_calls=[{
        "name": "get_weather",
        "args": {"location": "San Francisco"},
        "id": "call_123"
    }]
)

# Execute tool and create result message
weather_result = "Sunny, 72°F"
tool_message = ToolMessage(
    content=weather_result,
    tool_call_id="call_123"  # Must match the call ID
)

# Continue conversation
messages = [
    HumanMessage("What's the weather in San Francisco?"),
    ai_message,  # Model's tool call
    tool_message,  # Tool execution result
]
response = model.invoke(messages)  # Model processes the result

# %%
tool_message
# Out:
# ToolMessage(content='Sunny, 72°F', tool_call_id='call_123')

# %%
response
# Out:
# AIMessage(content='The current weather in San Francisco is sunny with a temperature of 72°F (22°C).', additional_kwargs={}, response_metadata={'model': 'granite4.1:3b', 'created_at': '2026-05-24T19:59:45.1772347Z', 'done': True, 'done_reason': 'stop', 'total_duration': 2927390300, 'load_duration': 58534000, 'prompt_eval_count': 56, 'prompt_eval_duration': 1308362300, 'eval_count': 20, 'eval_duration': 1418967700, 'logprobs': None, 'model_name': 'granite4.1:3b', 'model_provider': 'ollama'}, id='lc_run--019e5b92-68a9-7140-a22b-bd530a1ad117-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 56, 'output_tokens': 20, 'total_tokens': 76})
