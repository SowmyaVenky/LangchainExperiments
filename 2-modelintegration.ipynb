# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("granite4.1:3b", model_provider="ollama")
model
# Out:
# ChatOllama(output_version=None, model='granite4.1:3b')

# %%
## invoke the model
response=model.invoke("Hello How are you?")
response.content
# Out:
# 'I’m doing well, thank you. How can I assist you today?'

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("tinyllama:1.1b", model_provider="ollama")
response=model.invoke("why is the sky blue?")
response.content
# Out:
# "There's no one-size-fits-all answer to this question, as the sky can vary depending on its location and altitude. The reason why the sky is blue in many parts of the world is a combination of several factors:\n\n1. Sunlight: Most of the sunlight that reaches the earth's surface is reflected back into space by the atmosphere, which contributes to creating the beautiful colors we see in the sky.\n\n2. Temperature and Pressure: The pressure and temperature at different altitudes around the world can affect how much blue light is reflected from the earth, as well as how much red and green light are absorbed by the atmosphere.\n\n3. Atmospheric Conditions: In some parts of the world, such as in areas with high clouds or fog, the sky may appear blue due to a combination of refraction and scattering of sunlight. These conditions can also affect how much red and green light are absorbed by the atmosphere.\n\n4. Time of Day: Some days, when there is less cloud cover or more bright sunlight, the sky may appear bluer. Additionally, nighttime conditions can affect how blue or gray the sky appears, depending on the amount and type of light emitted by the stars.\n\nOverall, the reason why the sky appears blue depends on a combination of factors that are influenced by temperature, pressure, humidity, clouds, fog, and more. However, regardless of its color, the blue sky is one of the most beautiful sights in the world, serving as a reminder of our place in nature and the incredible beauty of the earth's atmosphere."

# %% [markdown]
# Streaming And Batch
# Streaming
# Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses. Calling stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time:

# %%
model.invoke("Write me a 50 words paragraph on Artificial Intelligence")
# Out:
# AIMessage(content="Artificial intelligence (AI) is a rapidly evolving field that promises to transform various industries, including healthcare, finance, and manufacturing. While AI has the potential to revolutionize certain aspects of these industries, it also poses significant challenges that require careful consideration and solutions to overcome.\n\nOne of the most prominent areas where AI is currently being applied is in healthcare. Artificially intelligent tools like chatbots and voice assistants have been utilized by hospitals and clinics for patient communication and care management, reducing wait times and improving patient outcomes. AI-powered diagnostic tools are also helping doctors to identify disease patterns and predict diagnoses more accurately.\n\nAnother area where AI is making significant contributions is in the financial sector. Artificial intelligence algorithms like machine learning and deep learning have been utilized for investment management, portfolio optimization, and risk assessment. This has led to a reduction in trading costs, better-informed investor decisions, and improved overall asset allocation strategies.\n\nDespite these impressive developments, there are also significant challenges that AI must address. One of the most critical issues is ensuring the safety and security of data and systems. As AI-powered tools become more sophisticated and interconnected, this becomes even more important.\n\nAnother challenge is how AI can interact with humans in a way that's both efficient and engaging. This requires developing models that can accurately understand human communication styles and preferences, which are becoming increasingly complex due to advances in speech recognition technology.\n\nFinally, it must also consider the potential social impact of AI. As AI becomes more advanced, it could create new employment opportunities but also lead to job displacement for certain sectors. Governments need to address this issue and develop policies that address the needs and benefits of both humans and machines working together.\n\nIn conclusion, while there are significant challenges that AI must face, the benefits of artificial intelligence in various industries are numerous and unparalleled. By utilizing AI for healthcare, investment management, and financial decision-making, the world can be transformed into a more efficient, cost-effective, and socially responsible place.", additional_kwargs={}, response_metadata={'model': 'tinyllama:1.1b', 'created_at': '2026-05-23T20:57:26.4032977Z', 'done': True, 'done_reason': 'stop', 'total_duration': 13731138100, 'load_duration': 512001400, 'prompt_eval_count': 49, 'prompt_eval_duration': 530596600, 'eval_count': 490, 'eval_duration': 10655032000, 'logprobs': None, 'model_name': 'tinyllama:1.1b', 'model_provider': 'ollama'}, id='lc_run--019e56a0-b2de-73e3-9108-4b34d287fdc5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 49, 'output_tokens': 490, 'total_tokens': 539})

# %%
for chunk in model.stream("Write me a 50 words paragraph on Artificial Intelligence"):
    print(chunk.text, end="|", flush=True)
# Out:
# Art|ific|ial| intelligence| (|AI|)| has| the| potential| to| revolution|ize| various| indust|ries| and| transform| human| life| in| count|less| ways|.| In| the| world| of| technology|,| A|I| is| considered| as| one| of| the| most| advanced| techn|ologies| that| can| enh|ance| product|ivity|,| efficiency|,| and| performance| in| various| areas|.| However|,| A|I| cannot| solve| every| problem| or| address| all| challeng|es| faced| by| humans|.|
# |
# |AI| is| an| intellig|ent| system| designed| to| simulate| human| intelligence| and| operate| autonom|ously|.| Its| development| began| with| simple| tasks| like| playing| ch|ess| or| solving| complex| mathematical| equations|.| Over| time|,| A|I| has| been| used| for| a| wide| range| of| applications| in| various| indust|ries| like| health|care|,| fin|ance|,| education|,| and| manufact|uring|.|
# |
# |One| area| where| A|I| is| already| making| an| impact| is| in| health|care|.| For| instance|,| A|I|-|based| systems| are| being| developed| to| analyze| medical| data|,| detect| dise|ases| early| and| treat| them| with| the| appropriate| medic|ation|.| In| addition|,| A|I| has| been| used| for| diagn|osis| of| complex| medical| conditions| such| as| cancer| or| Al|z|heimer|'|s| disease|,| providing| personal|ized| treatment| options| that| can| significantly| improve| patient| out|comes|.|
# |
# |An|other| area| where| A|I| is| making| a| significant| impact| is| in| education|.| Art|ific|ial| intelligence| algorithms| have| been| designed| to| autom|ate| learning| and| teaching| processes|,| en|abling| educ|ators| to| provide| personal|ized| learning| experiences| for| students|.| By| lever|aging| A|I|-|based| simulations| and| games|,| teachers| can| simulate| real|-|world| scenarios| and| help| students| better| understand| complex| concepts|.|
# |
# |In| the| world| of| manufact|uring|,| A|I| has| revolution|ized| production| processes| by| helping| companies| stream|line| their| workflow|s|.| A|I|-|power|ed| systems| can| monitor| production| lines| in| real|-|time| and| detect| issues| that| require| immediate| attention| to| prevent| del|ays| or| production| dow|nt|ime|.| Additionally|,| A|I| systems| have| been| developed| for| predict|ive| maintenance|,| ident|ifying| potential| issues| before| they| occur| and| providing| pro|active| maintenance| measures|.|
# |
# |In| the| fin|ance| sector|,| A|I| has| enabled| financial| institutions| to| process| vast| amounts| of| data| in| real|-|time|,| making| informed| dec|isions| about| invest|ments|,| lo|ans|,| and| credit| programs|.| This| has| resulted| in| improved| profit|ability| and| customer| satisfaction|.|
# |
# |Des|p|ite| its| enorm|ous| potential|,| A|I| also| pos|es| significant| challeng|es| that| must| be| addressed| before| it| can| be| fully| har|ness|ed| for| human| use|.| One| such| challenge| is| data| priv|acy| and| security|,| as| A|I| systems| rely| heavily| on| large| amounts| of| sensitive| data| to| operate|.| To| address| this| issue|,| govern|ments| and| indust|ries| are| working| towards| developing| standards| and| policies| around| data| protection|.|
# |
# |In| conclusion|,| Art|ific|ial| Int|elligence| holds| trem|end|ous| potential| for| human|ity|,| transform|ing| various| se|ctors| with| its| capabilities| in| autom|ation|,| diagn|osis|,| education|,| manufact|uring|,| and| fin|ance|.| While| it| has| already| revolution|ized| certain| areas|,| the| future| of| A|I| is| full| of| possibilities|,| including| more| personal|ization|,| sust|ain|ability|,| and| efficiency|.| As| this| technology| continues| to| develop|,| we| can| expect| a| world| where| machines| out|perform| humans| at| various| tasks|.|||

# %%
model.invoke("Why do parrots have colorful feathers?")
# Out:
# AIMessage(content="Parrots (also known as macaws) have different colors and patterns of feathers to attract mates, communicate with other birds, and provide camouflage against their surroundings. These patterns and colors often reflect the bird's social status, individuality, or mood, depending on the species. \n\nParrots use their feathers not only for color but also for texture, heat insulation, and waterproofing. Some birds have black, orange, and green feathers while others have brown, yellow, and blue feathers. The colors and patterns of these feathers are often used to signal to other birds the gender, age, size, mood, or social status of the bird.\n\nIn addition, some parrots also use their feathers to communicate with each other, such as to indicate whether they are ready for mating or if they're just passing by. This is important because parrot species often face competition from other birds for access to resources like food and mates. By using colors and patterns, parrots can help them stand out in the crowded bird world.\n\nIn summary, the colorful feathers of parrots are a product of their social behaviors and cultural traditions. They use these feathers as a way to attract mates, communicate with other birds, and evoke specific emotions or responses from other birds. The colors and patterns of their feathers may reflect their own identity, personality traits, or social status.", additional_kwargs={}, response_metadata={'model': 'tinyllama:1.1b', 'created_at': '2026-05-23T20:58:52.4861815Z', 'done': True, 'done_reason': 'stop', 'total_duration': 8194920800, 'load_duration': 47001500, 'prompt_eval_count': 45, 'prompt_eval_duration': 234310100, 'eval_count': 314, 'eval_duration': 5647976500, 'logprobs': None, 'model_name': 'tinyllama:1.1b', 'model_provider': 'ollama'}, id='lc_run--019e56a2-18c2-7c91-84ce-4fbfeb9d6883-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 45, 'output_tokens': 314, 'total_tokens': 359})

# %%
for chunk in model.stream("Why do parrots have colorful feathers?"):
    print(chunk.text, end="|", flush=True)
# Out:
# Par|ro|ts|,| like| humans|,| have| natural| colors| and| patterns| on| their| fe|athers| to| help| them| cam|ou|fl|age| and| identify| each| other| in| the| environment|.| Some| of| the| most| commonly| observed| colors| and| patterns| in| par|rot| fe|athers| include| black|,| white|,| yellow|,| blue|,| green|,| pur|ple|,| p|ink|,| brown|,| and| orange|.| These| fe|ather| colors| and| patterns| are| adapted| for| different| social| behav|iors| and| m|ating| success| among| par|ro|ts|.| Par|ro|ts| use| their| fe|athers| not| only| as| protection| against| pred|ators| but| also| to| attract| m|ates| or| to| communicate| with| each| other| through| vocal|izations|.| Over|all|,| fe|ather| color|ing| in| par|ro|ts| serves| a| functional| purpose| for| these| birds| and| has| helped| them| surv|ive| in| the| natural| environment| they| live| in|.|||

# %% [markdown]
# Batch
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel:

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
])
for response in responses:
    print(response)
# Out:
# content='Parrots, also known as psittacids, have bright and colorful feathers due to their dietary preferences. Parrots typically consume a variety of fruits, seeds, and nectar from different trees and plants, which contains various colors of pigments. The pigments found in the feathers are responsible for giving them a vivid coloration that can be adapted based on their environment. For example, bright yellow feathers indicate high food availability in tropical areas, while deep green feathers indicate abundant food sources in sub-tropical or cooler regions. The colors also help parrots detect the presence of predators or danger, and they are an important visual cue for navigation and communication. Overall, the feathers of parrots serve as vital tools to adapt their appearance and behavior based on their environment, helping them survive and thrive in their habitat.' additional_kwargs={} response_metadata={'model': 'tinyllama:1.1b', 'created_at': '2026-05-23T21:00:32.089513Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4873047700, 'load_duration': 37900000, 'prompt_eval_count': 45, 'prompt_eval_duration': 24981800, 'eval_count': 192, 'eval_duration': 3647137600, 'logprobs': None, 'model_name': 'tinyllama:1.1b', 'model_provider': 'ollama'} id='lc_run--019e56a3-aacd-7142-ab9b-8fea110a486c-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 45, 'output_tokens': 192, 'total_tokens': 237}
# content="Airplanes fly due to the force of aerodynamics, which is created by the movement of air around the wings and fuselage. The airplane's design includes an aerodynamic shape that maximizes lift while minimizing drag. This design helps to increase the plane's speed and altitude without consuming too much fuel or energy.\n\nThe propeller on the bottom of the wing, known as the rudder, uses lift to power it forward. The engine on top of the wing, called the engine cowl, uses thrust to push the plane forward. These two engines together provide the airplane with lift and thrust, allowing the aircraft to fly.\n\nWhen taking off or landing, the pilot turns the throttle backward to reduce speed and increase power, which causes the wings to lift more. As the wings lift, they generate lift and drag, causing the plane to rise upwards. This rise in altitude is what makes airplanes fly high into the sky.\n\nAs an airplane approaches its target destination, the plane's wings begin to lose lift due to wind resistance. In order to maintain speed and altitude, the pilot applies more power, which causes the engines to spin faster and use more fuel. The resulting increase in speed allows the airplane to reach the final destination at a higher altitude.\n\nAirplanes are notorious for their ability to fly through clouds, due to the aerodynamic forces they exert on the sky. However, in modern aircraft, advanced technology has been developed that allows pilots to maneuver and control the plane through the clouds to reach their destination." additional_kwargs={} response_metadata={'model': 'tinyllama:1.1b', 'created_at': '2026-05-23T21:00:40.9862438Z', 'done': True, 'done_reason': 'stop', 'total_duration': 13769778500, 'load_duration': 40019900, 'prompt_eval_count': 41, 'prompt_eval_duration': 140910800, 'eval_count': 343, 'eval_duration': 6624789500, 'logprobs': None, 'model_name': 'tinyllama:1.1b', 'model_provider': 'ollama'} id='lc_run--019e56a3-aace-7c03-8b1b-d793ec8030dc-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 41, 'output_tokens': 343, 'total_tokens': 384}
# content="Quantum computing, also known as quantum computation or QC, is a type of computing that exploits the properties of quantum mechanics to carry out complex mathematical operations much faster and more efficiently than traditional classical computers. In quantum computing, qubits (quantum bits) are used to represent information, which can be in various states depending on their position relative to an external field. \n\nIn a typical classical computer, each bit (or byte) represents just one binary digit (0 or 1). In a quantum computer, the number of logical qubits is infinite and can be manipulated with complex mathematical operations. This allows for much faster computing speeds and more efficient use of hardware resources compared to traditional computers.\n\nQuantum computing has many potential applications in fields such as cryptography, machine learning, drug discovery, and finance. However, quantum computers are still being developed and have not yet reached the commercial level due to technical challenges such as the limited number of qubits available on today's hardware." additional_kwargs={} response_metadata={'model': 'tinyllama:1.1b', 'created_at': '2026-05-23T21:00:46.2805691Z', 'done': True, 'done_reason': 'stop', 'total_duration': 19063599000, 'load_duration': 40042900, 'prompt_eval_count': 39, 'prompt_eval_duration': 169725500, 'eval_count': 208, 'eval_duration': 3712590000, 'logprobs': None, 'model_name': 'tinyllama:1.1b', 'model_provider': 'ollama'} id='lc_run--019e56a3-aacf-7d10-b8a4-430d9ce9d138-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 39, 'output_tokens': 208, 'total_tokens': 247}

# %%
model.batch(
    ["Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"],
    config={
        'max_concurrency': 2,  # Limit to 2 parallel calls
    }
)
# Out:
# [AIMessage(content="Parrots, also known as psittacids, have brightly colored feathers for several reasons. Here are some of the possible reasons:\n\n1. Behavioral adaptations: Colored feathers may be a social adaptation, particularly in birds that live in groups like parrots do. When allied members perceive each other as threats or unfamiliar, they may display bright colors to warn others about the presence of predators or potential competition for resources.\n\n2. Different dietary needs: Colored feathers may reflect different nutrient requirements depending on the bird's environment. For example, some tropical birds have brightly colored feathers that help them to blend in with their leafy surroundings while other species have duller feathers that reflect light and make them easier to spot from a distance.\n\n3. Adaptations for courtship: Parrots use colorful feathers as aids during mating rituals. The brightly colored feathers attract potential mates, while the duller ones may signal the presence of a competitor.\n\n4. Insects: While some parrot species are not known to eat insects, there is evidence that some species do use them as prey and that their coloration reflects their diet. For example, some species of macaw feathers have a pattern of black bars that suggest the presence of small, soft-bodied insects.\n\nIn summary, colored feathers are often used by parrots for behavioral, nutritional, and courtship adaptations. The precise reasons and contexts in which they appear can be complex and evolved over time.", additional_kwargs={}, response_metadata={'model': 'tinyllama:1.1b', 'created_at': '2026-05-23T21:01:56.9036159Z', 'done': True, 'done_reason': 'stop', 'total_duration': 17120164900, 'load_duration': 33461500, 'prompt_eval_count': 45, 'prompt_eval_duration': 157489100, 'eval_count': 355, 'eval_duration': 6563316200, 'logprobs': None, 'model_name': 'tinyllama:1.1b', 'model_provider': 'ollama'}, id='lc_run--019e56a4-c645-7530-aaba-677892f84e0d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 45, 'output_tokens': 355, 'total_tokens': 400}),
#  AIMessage(content="Airplanes (or aircraft) are propelled by thrusters or jet engines, which produce a high-pressure airflow that generates lift to move the aircraft forward. The lift generated by the engine is called drag force, which can either act against the airplane or help it fly forward. There are several different types of engines used in airplanes, including turbofan and turboprop engines, as well as jet engines that are typically powered by liquid fuel like kerosene.\n\nThe design of an aircraft is optimized to minimize drag while maximizing lift, allowing it to fly efficiently and safely. The wings, for example, are designed to create a large horizontal surface area, which generates lift from the airflow over them. The plane's body is also designed with streamlined surfaces to reduce drag and increase lift, such as the wingspan, length of fuselage, and tail fin.\n\nTo determine where to fly and how fast to go, an airplane's computer systems use a complex combination of calculations based on weather information, flight plans, and other inputs to generate a flight path. During takeoff or landing, the engines will be throttled up to increase lift and reduce drag, while cruising altitude will be maintained to optimize fuel consumption.\n\nOverall, airplane design is aimed at optimizing speed, efficiency, and safety during flight, making it one of the most efficient modes of transportation for large distances.", additional_kwargs={}, response_metadata={'model': 'tinyllama:1.1b', 'created_at': '2026-05-23T21:01:47.7574039Z', 'done': True, 'done_reason': 'stop', 'total_duration': 7973952900, 'load_duration': 32922200, 'prompt_eval_count': 41, 'prompt_eval_duration': 184311900, 'eval_count': 306, 'eval_duration': 5931280700, 'logprobs': None, 'model_name': 'tinyllama:1.1b', 'model_provider': 'ollama'}, id='lc_run--019e56a4-c646-76d1-89a7-636a2e04a927-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 306, 'total_tokens': 347}),
#  AIMessage(content='Quantum computing is a type of computer architecture that utilizes the properties and behavior of quantum bits (also known as qubits), which can exist in multiple states simultaneously, rather than just one state like classical computers. Unlike classical computers, quantum computers can perform complex calculations much faster than classical computers.\n\nIn a traditional computer, data is stored as an ordered sequence of bits or bytes called a "bitstring." In a quantum computer, the same bitstrings are stored as qubits in a superposition of states, making them ideal for performing complex calculations. The advantage of quantum computing is that it can perform computations that would take classical computers many times longer, allowing for faster and more efficient processing of data.\n\nSome important features of quantum computers include:\n\n1. Quantum parallelism: Quantum computing uses the principle of quantum parallelism, which allows multiple qubits to perform calculations simultaneously, resulting in improved performance and efficiency.\n\n2. Entanglement: Entangled states, where two or more qubits are in a superposition state at the same time, allow for faster and more efficient computations.\n\n3. Quantum logic gates: The use of quantum logic gates (QCGLs) allows for more complex computations than classical computers. For example, quantum computers can perform multiplication using QCGLs, which would require many iterations in a classical computer.\n\n4. Difficulty level: Unlike classical computers that can handle only certain types of problems, quantum computers have a "hardware-defined problem" architecture, meaning they are designed to handle specific types of problems better than classical computers.', additional_kwargs={}, response_metadata={'model': 'tinyllama:1.1b', 'created_at': '2026-05-23T21:02:05.4774939Z', 'done': True, 'done_reason': 'stop', 'total_duration': 17719011700, 'load_duration': 32026900, 'prompt_eval_count': 39, 'prompt_eval_duration': 94530600, 'eval_count': 337, 'eval_duration': 6247317400, 'logprobs': None, 'model_name': 'tinyllama:1.1b', 'model_provider': 'ollama'}, id='lc_run--019e56a4-e56e-7840-8696-1a51a353be05-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 337, 'total_tokens': 376})]
